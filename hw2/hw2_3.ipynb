# %%
import cv2
import numpy as np
from skimage import io
from matplotlib import pyplot as plt

# %%
def adaptive(grayscaled, blocksize=15, param=5):
    return cv2.adaptiveThreshold(grayscaled, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, blocksize, param)


def blur_threshold(grayscaled, th, k_size=5):
    image1 = cv2.GaussianBlur(grayscaled,(k_size,k_size),0) 
    ret, image2 = cv2.threshold(image1, th, 255, cv2.THRESH_BINARY)
    return image2

def otsu(grayscaled):
    retval, im = cv2.threshold(grayscaled, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return im

# %% [markdown]
# ## Image 1

# %%
img = cv2.cvtColor(io.imread("tasks/object/obj1.jpg"), cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
(w,h) = img.shape[:2]
mask = np.zeros((w,h),np.uint8)
mask[100:200, 200:300] = 1
mask[0:100, 0:50] = 0
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (25,25,450,200)
mask, bgdModel, fgdModel = cv2.grabCut(img,mask,rect,bgdModel,fgdModel,50,cv2.GC_INIT_WITH_RECT)
mask = np.where((mask==2)|(mask==0),0,1).astype('uint8')
image_segmented = img*mask[:,:,np.newaxis]

# %%
plt.imshow(cv2.cvtColor(image_segmented, cv2.COLOR_BGR2RGB))

# %%
img = cv2.cvtColor(io.imread("tasks/object/obj2.jpg"), cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
(w,h) = img.shape[:2]
mask = np.zeros((w,h),np.uint8)
mask[100:200, 200:300] = 1
mask[0:100, 0:50] = 0
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (50,50,450,260)
mask, bgdModel, fgdModel = cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)
mask = np.where((mask==2)|(mask==0),0,1).astype('uint8')
image_segmented = img*mask[:,:,np.newaxis]

# %%
plt.imshow(cv2.cvtColor(image_segmented, cv2.COLOR_BGR2RGB))

# %%
img = cv2.cvtColor(io.imread("tasks/object/obj3.jpg"), cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
(w,h) = img.shape[:2]
mask = np.zeros((w,h),np.uint8)
mask[100:200, 200:300] = 1
mask[0:100, 0:50] = 0
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (50,50,250,250)
mask, bgdModel, fgdModel = cv2.grabCut(img,mask,rect,bgdModel,fgdModel,10,cv2.GC_INIT_WITH_RECT)
mask = np.where((mask==2)|(mask==0),0,1).astype('uint8')
image_segmented = img*mask[:,:,np.newaxis]
plt.imshow(cv2.cvtColor(image_segmented, cv2.COLOR_BGR2RGB))

# %%
img = cv2.cvtColor(io.imread("tasks/object/obj4.jpg"), cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
(w,h) = img.shape[:2]
mask = np.zeros((w,h),np.uint8)
mask[100:200, 200:300] = 1
mask[0:100, 0:50] = 0
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (50,10,420,300)
mask, bgdModel, fgdModel = cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)
mask = np.where((mask==2)|(mask==0),0,1).astype('uint8')
image_segmented = img*mask[:,:,np.newaxis]
plt.imshow(cv2.cvtColor(image_segmented, cv2.COLOR_BGR2RGB))

# %%
img = cv2.cvtColor(io.imread("tasks/object/obj5.jpg"), cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
(w,h) = img.shape[:2]
mask = np.zeros((w,h),np.uint8)
mask[100:200, 200:300] = 1
mask[0:100, 0:50] = 0
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (50,10,420,300)
mask, bgdModel, fgdModel = cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)
mask = np.where((mask==2)|(mask==0),0,1).astype('uint8')
image_segmented = img*mask[:,:,np.newaxis]
plt.imshow(cv2.cvtColor(image_segmented, cv2.COLOR_BGR2RGB))

# %%
img = cv2.cvtColor(io.imread("tasks/object/obj6.jpg"), cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
(w,h) = img.shape[:2]
mask = np.zeros((w,h),np.uint8)
mask[100:200, 200:300] = 1
mask[0:100, 0:50] = 0
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (70,70,250,450)
mask, bgdModel, fgdModel = cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)
mask = np.where((mask==2)|(mask==0),0,1).astype('uint8')
image_segmented = img*mask[:,:,np.newaxis]
plt.imshow(cv2.cvtColor(image_segmented, cv2.COLOR_BGR2RGB))
